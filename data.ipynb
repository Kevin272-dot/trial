# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple sine wave')
plt.show()

# %%
import numpy as np
a1 = np.array([[1,3,4], [2,4,5]])
a2 = np.array([[1, 3]])
print(a1.shape)
print(a2.shape)
result = a1 + a2.reshape(2,1)
print(result)
# Out:
# (2, 3)
# (1, 2)
# [[2 4 5]
#  [5 7 8]]

# %%
plt.plot(x, np.sin(x**2))
plt.title('A simple sine wave')
plt.show()

# %%
import numpy as np

# Create a 2x3 array filled with the value 7.0
my_array = np.full(10000000, 0.1)
my = np.sum(my_array)
print(my)

# %%
import pandas as pd
df = pd.read_csv("sample_data.csv")
print(df.head())
print(df.plot(kind='scatter', x='Age', y='Salary', title='Salary vs Age'))
plt.show()
# Out:
#    ID   Name  Age Department    Salary
# 0   1  QAHFT   38  Marketing  48676.40
# 1   2  RXCKA   22         IT  85116.22
# 2   3  FNAFQ   18         HR  37566.69
# 3   4  OFPVA   47         HR  91051.67
# 4   5  USIEY   57  Marketing  90101.53
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df.iloc[10])
# Out:
# ID               11
# Name          JFGYQ
# Age              50
# Department       IT
# Salary          NaN
# Name: 10, dtype: object

# %%
print(df.query('Department == "IT" and Salary > 50000'))
# Out:
#     ID   Name  Age Department    Salary
# 1    2  RXCKA   22         IT  85116.22
# 8    9  SBFHC   52         IT  51363.36
# 29  30  FOSFI   37         IT  80998.15
# 30  31  ZQLND   60         IT  51957.41
# 32  33  BQFXW   26         IT  65799.61
# 36  37  SRZCK   65         IT  79614.97
# 47  48  DXGPQ   58         IT  51974.10

# %%
df = pd.read_csv("sample_data.csv") 
df.fillna(df["Salary"].mean(), inplace = True)
print(df)
# Out:
#     ID   Name  Age Department        Salary
# 0    1  QAHFT   38  Marketing  48676.400000
# 1    2  RXCKA   22         IT  85116.220000
# 2    3  FNAFQ   18         HR  37566.690000
# 3    4  OFPVA   47         HR  91051.670000
# 4    5  USIEY   57  Marketing  90101.530000
# 5    6  ICCWP   54         IT  45570.360000
# 6    7  USNZJ   24         HR  87161.060000
# 7    8  OVQWP   22         HR  62221.230000
# 8    9  SBFHC   52         IT  51363.360000
# 9   10  GCHQJ   31    Finance  85674.180000
# 10  11  JFGYQ   50         IT  67160.404167
# 11  12  PESEJ   34    Finance  31656.510000
# 12  13  ZQORV   26  Marketing  67160.404167
# 13  14  UFAIG   40      Sales  52978.340000
# 14  15  FYWIR   22  Marketing  90504.710000
# 15  16  KXLGG   33      Sales  97682.240000
# 16  17  OGPXK   41         HR  49538.750000
# 17  18  FZNCB   36         HR  74903.720000
# 18  19  CQUKB   28         HR  57977.490000
# 19  20  JZNZW   46    Finance  98680.480000
# ...

# %%
df = pd.read_csv("sample_data.csv") 
df["Salary"].fillna(df.loc[df["Department"]== "IT" , "Salary"].mean(), inplace = True)
print(df)
# Out:
#     ID   Name  Age Department        Salary
# 0    1  QAHFT   38  Marketing  48676.400000
# 1    2  RXCKA   22         IT  85116.220000
# 2    3  FNAFQ   18         HR  37566.690000
# 3    4  OFPVA   47         HR  91051.670000
# 4    5  USIEY   57  Marketing  90101.530000
# 5    6  ICCWP   54         IT  45570.360000
# 6    7  USNZJ   24         HR  87161.060000
# 7    8  OVQWP   22         HR  62221.230000
# 8    9  SBFHC   52         IT  51363.360000
# 9   10  GCHQJ   31    Finance  85674.180000
# 10  11  JFGYQ   50         IT  61163.122222
# 11  12  PESEJ   34    Finance  31656.510000
# 12  13  ZQORV   26  Marketing  61163.122222
# 13  14  UFAIG   40      Sales  52978.340000
# 14  15  FYWIR   22  Marketing  90504.710000
# 15  16  KXLGG   33      Sales  97682.240000
# 16  17  OGPXK   41         HR  49538.750000
# 17  18  FZNCB   36         HR  74903.720000
# 18  19  CQUKB   28         HR  57977.490000
# 19  20  JZNZW   46    Finance  98680.480000
# ...

# %%
df = pd.read_csv("sample_data.csv") 
df["Salary"].fillna(df.iloc[1:20]["Salary"].mean(), inplace = True)
print(df)
# Out:
#     ID   Name  Age Department        Salary
# 0    1  QAHFT   38  Marketing  48676.400000
# 1    2  RXCKA   22         IT  85116.220000
# 2    3  FNAFQ   18         HR  37566.690000
# 3    4  OFPVA   47         HR  91051.670000
# 4    5  USIEY   57  Marketing  90101.530000
# 5    6  ICCWP   54         IT  45570.360000
# 6    7  USNZJ   24         HR  87161.060000
# 7    8  OVQWP   22         HR  62221.230000
# 8    9  SBFHC   52         IT  51363.360000
# 9   10  GCHQJ   31    Finance  85674.180000
# 10  11  JFGYQ   50         IT  69985.208235
# 11  12  PESEJ   34    Finance  31656.510000
# 12  13  ZQORV   26  Marketing  69985.208235
# 13  14  UFAIG   40      Sales  52978.340000
# 14  15  FYWIR   22  Marketing  90504.710000
# 15  16  KXLGG   33      Sales  97682.240000
# 16  17  OGPXK   41         HR  49538.750000
# 17  18  FZNCB   36         HR  74903.720000
# 18  19  CQUKB   28         HR  57977.490000
# 19  20  JZNZW   46    Finance  98680.480000
# ...

# %%
print(df.shape)

print(df.groupby("Department")["Salary"].mean().plot(kind="pie"))
plt.title("Average Salary by Department")
plt.show()
# Out:
# (50, 5)
# Axes(0.22375,0.11;0.5775x0.77)

# %%
print(df.shape)
print(df.groupby("Department")["Salary"].max())
# Out:
# (50, 5)
# Department
# Finance      98680.48
# HR           95746.60
# IT           85116.22
# Marketing    94790.26
# Sales        97928.04
# Name: Salary, dtype: float64

# %%
import pandas as pd 
df = pd.read_csv("sample_data.csv")
df.drop_duplicates(inplace=True)

# %%
df = pd.read_csv("sample_data.csv") 
df.fillna(df.query('Department == "IT"')["Salary"].mean(), inplace = True)
print(df)

# %%
df = pd.read_csv("sample_data.csv")
print(df.sort_values(by = "Name", ascending = True))
# Out:
#     ID   Name  Age Department    Salary
# 20  21  ASRNG   52      Sales  67535.10
# 33  34  BGRFD   34    Finance  56963.68
# 32  33  BQFXW   26         IT  65799.61
# 46  47  CEPRG   61    Finance  53114.00
# 18  19  CQUKB   28         HR  57977.49
# 47  48  DXGPQ   58         IT  51974.10
# 35  36  ECLLM   24         HR  47830.58
# 31  32  FIPFF   24         HR  72434.62
# 41  42  FKBJZ   56    Finance  81936.51
# 2    3  FNAFQ   18         HR  37566.69
# 29  30  FOSFI   37         IT  80998.15
# 14  15  FYWIR   22  Marketing  90504.71
# 17  18  FZNCB   36         HR  74903.72
# 9   10  GCHQJ   31    Finance  85674.18
# 42  43  GULKY   31    Finance  76944.00
# 26  27  HBWYC   18  Marketing  48582.65
# 25  26  IAYWV   51    Finance  97377.40
# 5    6  ICCWP   54         IT  45570.36
# 37  38  IWGEL   53      Sales  30118.39
# 10  11  JFGYQ   50         IT       NaN
# 19  20  JZNZW   46    Finance  98680.48
# 38  39  KHGYL   27  Marketing  94790.26
# ...

# %%
print(df.agg({'Salary': ['mean', 'max', 'min'], 'Age': ['mean', 'max', 'min']}))
# Out:
#             Salary   Age
# mean  67160.404167  40.8
# max   98680.480000  65.0
# min   30118.390000  18.0

# %%
print(df.pivot_table(index = 'Department', columns= 'Age', values = 'Salary'))
# Out:
# Age               18        22            24        25        26        27  \
# Department
# Finance          NaN       NaN           NaN  70361.16       NaN       NaN
# HR          37566.69  62221.23  69142.086667       NaN       NaN       NaN
# IT               NaN  85116.22           NaN       NaN  65799.61       NaN
# Marketing   48582.65  90504.71           NaN       NaN       NaN  94790.26
# Sales            NaN       NaN           NaN       NaN       NaN       NaN
#
# Age               28        31        33         34  ...        53        54  \
# Department                                           ...
# Finance          NaN  81309.09       NaN  44310.095  ...       NaN       NaN
# HR          57977.49  76496.64       NaN        NaN  ...  60419.46       NaN
# IT               NaN       NaN       NaN        NaN  ...       NaN  45570.36
# Marketing        NaN       NaN       NaN  89361.070  ...       NaN       NaN
# ...

# %%
print(df.drop("ID", axis=1, inplace=True))
# Out:
# None

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (20,10))
print(fig)
plt.show()
# Out:
# Figure(2000x1000)

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(2,2)
ax[0,1].plot([1,2,3],[4,5,6],color = "purple",linestyle = "dashed")
ax[1,1].bar(["A","B","C"],[7,8,9],color = ["red","blue","green"])
ax[0,0].scatter([1,2,3],[4,5,6],color = "orange")
ax[1,0].hist([1,2,1,4,5,4,7,5,7],edgecolor='black', bins = 5,color = "fuchsia")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Simple Line Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x,y)
plt.xticks(np.arange(0,11,2),['0', '2', '4', '6', '8', '10'])
plt.xticks(rotation=45)
plt.legend(['Sine Wave'])
plt.show()

# %%
import matplotlib.pyplot as plt
x= [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(['Data 1', 'Data 2'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('Time (days)')
plt.ylabel('stock price ($)')
plt.title('Stock Price Over Time')
plt.show()

# %%
import matplotlib.pyplot as plt
age = np.linspace(20, 60, 100)
income = age*500 + np.random.normal(0, 10000, 100)
plt.scatter(age, income)
plt.xlabel('Age')
plt.ylabel('Income ($)')
plt.title('Income vs Age')
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['Product A', 'Product B', 'Product C', 'Product D']
values = [1500, 2300, 1200, 3000]

plt.bar(categories, values, color =['blue', 'orange', 'green', 'red'])
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Product Sales Comparison')
plt.show()

# %%
import matplotlib.pyplot as plt
data = np.random.randn(1000)
plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')
plt.show()

# %%
import matplotlib.pyplot as plt
label = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
plt.pie(sizes, labels=label, autopct='%1.1f%%',colors = ['gold', 'lightblue', 'lightgreen', 'lightcoral'])
plt.title('Pie Chart Example')
plt.show()

# %%
import csv
import random

# Define list of regions
regions = ['North', 'South', 'East', 'West', 'Central']

# File name
filename = 'simple_car_sales_data.csv'

# Generate data
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(['Region', 'Units_Sold'])
    
    for _ in range(100):  # 100 rows
        region = random.choice(regions)
        units = random.randint(1, 50)  # Random units sold
        writer.writerow([region, units])

print(f"CSV file '{filename}' with 100 rows and 2 columns generated successfully.")
# Out:
# CSV file 'simple_car_sales_data.csv' with 100 rows and 2 columns generated successfully.

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('simple_car_sales_data.csv')
pl = px.scatter(df, x = 'Region', y = 'Units_Sold', title = 'Car Sales Data',color = "Region",color_discrete_sequence=px.colors.qualitative.Vivid,symbol = "Region")
pl.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv('simple_car_sales_data.csv')
df.groupby(df["Region"])["Units_Sold"].sum().plot(kind = "bar",x = "Region",y = "Units_Sold", title = "Total Units sold",color = ['purple', 'orange', 'green', 'blue', 'red'] )
plt.xlabel("Region")
plt.ylabel("Units Sold")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('simple_car_sales_data.csv')
dff = df.query('Region == "North"')['Units_Sold'].sum(), df.query('Region == "South"')['Units_Sold'].sum(), df.query('Region == "East"')['Units_Sold'].sum(), df.query('Region == "West"')['Units_Sold'].sum(), df.query('Region == "Central"')['Units_Sold'].sum()

plt.pie(dff, labels=["North", "South", "East", "West", "Central"], autopct='%1.1f%%', colors=['gold', 'lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Car Sales Distribution by Region')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('simple_car_sales_data.csv')

# Sum units sold per region
region_sales = df.groupby('Region')['Units_Sold'].sum()
print(region_sales)
# Plot the pie chart
plt.pie(region_sales, labels=region_sales.index, autopct='%1.1f%%',
        colors=['gold', 'lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Car Sales Distribution by Region')
plt.show()
# Out:
# Region
# Central    566
# East       333
# North      386
# South      637
# West       643
# Name: Units_Sold, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("simple_car_sales_data.csv")
dff = df.groupby(df["Region"])["Units_Sold"].sum() 
pl= plt.pie(dff, labels = dff.index,autopct = '%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,50,500)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("random")
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
iris= load_iris()
x = iris.data
y = iris.target
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Create a decision tree classifier
clf = DecisionTreeClassifier()

# Train the classifier
clf.fit(x_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(x_test) 
# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
print("Accuracy:", accuracy)
print("Recall:", recall)
# Out:
# Accuracy: 1.0
# Recall: 1.0
