# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple sine wave')
plt.show()

# %%
import numpy as np
a1 = np.array([[1,3,4], [2,4,5]])
a2 = np.array([[1, 3]])
print(a1.shape)
print(a2.shape)
result = a1 + a2.reshape(2,1)
print(result)

# %%
plt.plot(x, np.sin(x**2))
plt.title('A simple sine wave')
plt.show()

# %%
import numpy as np

# Create a 2x3 array filled with the value 7.0
my_array = np.full(10000000, 0.1)
my = np.sum(my_array)
print(my)

# %%
import pandas as pd
df = pd.read_csv("sample_data.csv")
print(df.head())

# %%
print(df.iloc[10])

# %%
print(df.query('Department == "IT" and Salary > 50000'))

# %%
df = pd.read_csv("sample_data.csv") 
df.fillna(df["Salary"].mean(), inplace = True)
print(df)

# %%
df = pd.read_csv("sample_data.csv") 
df.fillna(df.loc[df["Department"] == "IT", "Salary"].mean(), inplace = True)
print(df)

# %%
df = pd.read_csv("sample_data.csv") 
df.fillna(df.iloc[1:20]["Salary"].mean(), inplace = True)
print(df)

# %%
print(df.shape)
print(df.groupby("Department")["Salary"].mean().plot(kind="bar"))
plt.title("Average Salary by Department")
plt.show()
# Out:
# (50, 5)
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df.shape)
print(df.groupby("Department")["Salary"].sum())
# Out:
# (50, 5)
# Department
# Finance      906534.500000
# HR           813348.510000
# IT           620453.308235
# Marketing    566899.998235
# Sales        456433.500000
# Name: Salary, dtype: float64
